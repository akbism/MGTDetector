# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/GPT
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/GPT

# %%
import os, re
from os import walk
import pandas as pd

# %% [markdown]
# ## chatgpt-generated-text-detection-corpus (CGTD)

# %%
class gen_args:
    # folder path
    root_path = r'./chatgpt-generated-text-detection-corpus/full_texts'
    chatgpt_path = root_path + '/chatgpt'
    human_path = root_path + '/human'
    question_path = root_path + r'/questions.txt'
args_add=gen_args()

# %%
### Read all files from the folder and save to chatgpt_human_combined.csv
questions = pd.read_table(args_add.question_path, header=None)
questions['sr_no'] = questions[0].map(lambda x: re.findall(r"^[0-9]{1,3}" , x)[0].strip())
questions['question'] = questions[0].map(lambda x: re.split(r"^[0-9]{1,3}\) " , x)[1].strip())
# list to store files name
chatgpt_files = []
human_files = []
for (dir_path, dir_names, file_names) in walk(args_add.chatgpt_path):
    chatgpt_files.extend(file_names)

for (dir_path, dir_names, file_names) in walk(args_add.human_path):
    human_files.extend(file_names)
chatgpt_files_path = [os.path.join(args_add.chatgpt_path, f) for f in chatgpt_files]
human_files_path = [os.path.join(args_add.human_path, f) for f in human_files]
human_files_no = [re.split("\.",x)[0] for x in human_files]
chatgpt_files_no = [re.split("\.",x)[0] for x in chatgpt_files]

df_chatgpt=pd.DataFrame(columns=['sr_no', 'text'])
for i, f in zip(chatgpt_files_no, chatgpt_files_path):
  fileObject = open(f, "r")
  data = fileObject.read()
  # print(i)
  # print("------")
  # print(data)
  df_chatgpt = df_chatgpt.append({"sr_no":i, "text": data}, ignore_index=True)

df_human=pd.DataFrame(columns=['sr_no', 'text'])
for i, f in zip(human_files_no, human_files_path):
  fileObject = open(f, "r")
  data = fileObject.read()
  # print(i)
  # print("------")
  # print(data)
  df_human = df_human.append({"sr_no":i, "text": data}, ignore_index=True)

df_human['source']='human'
df_chatgpt['source']='chatgpt'
df_combined=pd.concat([df_human, df_chatgpt], axis=0)
df_combined.to_csv("chatgpt_human_combined.csv")

# %%
display(df_combined)
# Out:
#     sr_no                                               text   source
# 0     111  I think that, if people move to another countr...    human
# 1     102  Computers are one of the most prominent and ex...    human
# 2     108  If I had to travel to a place 40 miles away, I...    human
# 3     101  For the last five years of my life, I have bee...    human
# 4     106  It is a commonly accepted fact that society be...    human
# ..    ...                                                ...      ...
# 121    94  There are certainly advantages to living in a ...  chatgpt
# 122    97  There is no doubt that the exploration of oute...  chatgpt
# 123    93  If I could ask a famous person one question, I...  chatgpt
# 124     9  Television has been a popular form of entertai...  chatgpt
# 125    98  There are many different ways that people try ...  chatgpt
#
# [252 rows x 3 columns]

# %% [markdown]
# ## IELTS GPT35 Human Comparison Corpus(IGHC)

# %%
class gen_args:
    # folder path
    root_path = r'./our_dataset'
    chatgpt_path = root_path + '/chatgpt'
    human_path = root_path + '/human'
    question_path = root_path + r'/questions.csv'
args_add=gen_args()

# %%
questions.head()
# Out:
#        0                                                  1
# 0      0      Should We Preserve Past Historical Buildings?
# 1  10001  As computers are being used more and more in e...
# 2  10002  As computers are being used more and more in e...
# 3      2  In some countries young people are encouraged ...
# 4      3  Some people believe that a college or universi...

# %%
### Read all files from the folder and save to chatgpt_human_combined.csv
questions = pd.read_table(args_add.question_path, header=None, sep=",",encoding='cp1252', names=['sr_no', 'text'])
chatgpt_files = []
human_files = []
for (dir_path, dir_names, file_names) in walk(args_add.chatgpt_path):
    chatgpt_files.extend(file_names)

for (dir_path, dir_names, file_names) in walk(args_add.human_path):
    human_files.extend(file_names)
chatgpt_files_path = [os.path.join(args_add.chatgpt_path, f) for f in chatgpt_files]
human_files_path = [os.path.join(args_add.human_path, f) for f in human_files]
human_files_no = [re.split("\.",x)[0] for x in human_files]
chatgpt_files_no = [re.split("\.",x)[0] for x in chatgpt_files]

df_chatgpt=pd.DataFrame(columns=['sr_no', 'text'])
for i, f in zip(chatgpt_files_no, chatgpt_files_path):
  fileObject = open(f, "r")
  data = fileObject.read()
  # print(i)
  # print("------")
  # print(data)
  df_chatgpt = df_chatgpt.append({"sr_no":i, "text": data}, ignore_index=True)

df_human=pd.DataFrame(columns=['sr_no', 'text'])
for i, f in zip(human_files_no, human_files_path):
  fileObject = open(f, "r")
  data = fileObject.read()
  # print(i)
  # print("------")
  # print(data)
  df_human = df_human.append({"sr_no":i, "text": data}, ignore_index=True)

df_human['source']='human'
df_chatgpt['source']='chatgpt'
df_combined=pd.concat([df_human, df_chatgpt], axis=0)
df_combined.to_csv("IELTS_GPT35_Human_Comparison_Corpus.csv")

# %% [markdown]
# ## Detecting generated scientific papers (DagPap22)

# %%
class gen_args:
    root_path = r'./detecting-generated-scientific-papers'
args_add=gen_args()

# %%
file1= args_add.root_path +'/fake_papers_train_part_public_extended.csv'
file2= args_add.root_path +'/fake_papers_test_public_extended.csv'
df1=pd.read_csv(file1, index_col=0)
df2=pd.read_csv(file2, index_col=0)

# %%
df=pd.concat([df1, df2], axis=0)

# %%
df.source.value_counts()
# Out:
# sdg_abstracts_original     5846
# summarized_sdg             5844
# micpro_retracted           3212
# summarized_micpro          2583
# micpro_original            2583
# generated_micpro           2330
# generated_sdg              2294
# spinbot_paraphrased_sdg    1945
# generated_gpt3              116
# Name: source, dtype: int64

# %%
### Sample the human written text relevant to the current task
import random
df_sampled=df[df.source.isin(['sdg_abstracts_original', 'micpro_original'])].groupby('source', group_keys=False).apply(lambda x: x.sample(58))

# %%
df_sampled
# Out:
#                                                     text  \
# id
# 16811  A scalable elliptic curve cryptography (ECC) p...
# 16513  Design of dual port memory in QCA is an intere...
# 26583  The rapid increase in the use of microprocesso...
# 635    Event counting is a common function performed ...
# 19911  In delivering multimedia services, quality of ...
# ...                                                  ...
# 8100   This paper presents the experimental proof of ...
# 4663   ICT use in education is a key instrument to en...
# 8382   We investigate the critical behavior of disord...
# 25864  Background: Overexpression of the hypoxia indu...
# 17882  Despite the widely documented evidence that fa...
#
#                        source  fake
# id
# 16811         micpro_original     0
# 16513         micpro_original     0
# 26583         micpro_original     0
# 635           micpro_original     0
# 19911         micpro_original     0
# ...                       ...   ...
# 8100   sdg_abstracts_original     0
# 4663   sdg_abstracts_original     0
# 8382   sdg_abstracts_original     0
# 25864  sdg_abstracts_original     0
# 17882  sdg_abstracts_original     0
#
# [116 rows x 3 columns]

# %%
df_combined=pd.concat([df_sampled, df[df.source.isin(['generated_gpt3'])]], axis=0)
df_combined['source_org'] = df_combined['source']
df_combined['source'] = df_combined['fake'].map({0:'human', 1:'chatgpt'})
df_combined = df_combined.reset_index()
df_combined.rename(columns={'id': 'sr_no'}, inplace=True)

# %%
display(df_combined)
# Out:
#      sr_no                                               text   source  fake  \
# 0    16811  A scalable elliptic curve cryptography (ECC) p...    human     0
# 1    16513  Design of dual port memory in QCA is an intere...    human     0
# 2    26583  The rapid increase in the use of microprocesso...    human     0
# 3      635  Event counting is a common function performed ...    human     0
# 4    19911  In delivering multimedia services, quality of ...    human     0
# ..     ...                                                ...      ...   ...
# 227  25613  In this paper we extend the notion of minimum ...  chatgpt     1
# 228  26106  In this paper, we develop a linear programming...  chatgpt     1
# 229  26376  The effect of parental care in a social specie...  chatgpt     1
# 230  26584  In this paper, we supplement the work of Hall ...  chatgpt     1
# 231  26689  Recent studies have shown that the genetic var...  chatgpt     1
#
#           source_org
# 0    micpro_original
# 1    micpro_original
# 2    micpro_original
# 3    micpro_original
# 4    micpro_original
# ..               ...
# 227   generated_gpt3
# 228   generated_gpt3
# 229   generated_gpt3
# 230   generated_gpt3
# 231   generated_gpt3
#
# [232 rows x 5 columns]

# %%
df_combined.to_csv("DagPap22_Corpus.csv")
